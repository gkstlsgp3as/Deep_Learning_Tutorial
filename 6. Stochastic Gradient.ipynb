# %% [markdown]
# ## 6. Stochastic Gradient

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("homeprices_bang.csv")
df.sample(5)
# Out:
#     area  bedrooms  price
# 4   1200         2   51.0
# 12  1000         2   38.0
# 8   1310         3   50.0
# 9   3700         5  167.0
# 11  2785         4  140.0

# %%
from sklearn import preprocessing

sx = preprocessing.MinMaxScaler() # area & bedrooms
sy = preprocessing.MinMaxScaler() # price

scaled_X = sx.fit_transform(df.drop('price', axis='columns'))
scaled_x # convert them to 0~1
# Out:
# array([[0.08827586, 0.25      ],
#        [0.62068966, 0.75      ],
#        [0.22068966, 0.5       ],
#        [0.24862069, 0.5       ],
#        [0.13793103, 0.25      ],
#        [0.12758621, 0.25      ],
#        [0.6662069 , 0.75      ],
#        [0.86206897, 0.75      ],
#        [0.17586207, 0.5       ],
#        [1.        , 1.        ],
#        [0.34482759, 0.5       ],
#        [0.68448276, 0.75      ],
#        [0.06896552, 0.25      ],
#        [0.10344828, 0.25      ],
#        [0.5       , 0.5       ],
#        [0.12931034, 0.25      ],
#        [0.13103448, 0.5       ],
#        [0.25517241, 0.5       ],
#        [0.67931034, 0.5       ],
#        [0.        , 0.        ]])

# %%
scaled_y = sy.fit_transform(df['price'].values.reshape(df.shape[0],1))
scaled_y
# Out:
# array([[0.05237037],
#        [0.65185185],
#        [0.22222222],
#        [0.31851852],
#        [0.14074074],
#        [0.04444444],
#        [0.76296296],
#        [0.91111111],
#        [0.13333333],
#        [1.        ],
#        [0.37037037],
#        [0.8       ],
#        [0.04444444],
#        [0.05925926],
#        [0.51111111],
#        [0.07407407],
#        [0.11851852],
#        [0.20740741],
#        [0.51851852],
#        [0.        ]])

# %%
df['price'].values.shape
# Out:
# (20,)

# %%
df.shape[0]
# Out:
# 20

# %%
df['price'].reshape(df.shape[0],1) # Series cannot be reshaped -> use values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26916\966090119.py in <module>
# ----> 1 df['price'].reshape(df.shape[0],1) # Series cannot be reshaped -> use values
#
# ~\anaconda3\envs\TF_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
np.dot(w, scaled_X.T)
# Out:
# array([0.33827586, 1.37068966, 0.72068966, 0.74862069, 0.38793103,
#        0.37758621, 1.4162069 , 1.61206897, 0.67586207, 2.        ,
#        0.84482759, 1.43448276, 0.31896552, 0.35344828, 1.        ,
#        0.37931034, 0.63103448, 0.75517241, 1.17931034, 0.        ])

# %%
scaled_X.T
# Out:
# array([[0.08827586, 0.62068966, 0.22068966, 0.24862069, 0.13793103,
#         0.12758621, 0.6662069 , 0.86206897, 0.17586207, 1.        ,
#         0.34482759, 0.68448276, 0.06896552, 0.10344828, 0.5       ,
#         0.12931034, 0.13103448, 0.25517241, 0.67931034, 0.        ],
#        [0.25      , 0.75      , 0.5       , 0.5       , 0.25      ,
#         0.25      , 0.75      , 0.75      , 0.5       , 1.        ,
#         0.5       , 0.75      , 0.25      , 0.25      , 0.5       ,
#         0.25      , 0.5       , 0.5       , 0.5       , 0.        ]])

# %%
def batch_gradient_descent(X, y_true, epochs, learning_rate = 0.01):
    num_of_feat = X.shape[1]
    
    w = np.ones(shape = (num_of_feat)) # initialize weights as 1 
    b = 0
    total_samp = X.shape[0]
    
    for i in range(epochs):
        y_pred = np.dot(w* scaled_X.T) # w1*X['area'] + w2*X['bedrooms'] + b

# %%
w = np.ones(shape=(2))
